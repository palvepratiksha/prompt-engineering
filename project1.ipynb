# %% [markdown]
# <a href="https://colab.research.google.com/github/palvepratiksha/prompt-engineering/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# !pip install requests
import openai
import requests
from openai import OpenAI
# Out:
# Collecting openai
#   Downloading openai-1.52.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.52.2-py3-none-any.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 12.8 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.7 MB/s eta 0:00:00
# Downloading jiter-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 18.5 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.6.1 openai-1.52.2
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %%
import pandas as pd
import openai
import requests
from openai import OpenAI
import os

```python
import pandas as pd
import openai
import requests
from openai import OpenAI
import os


# Set your OpenAI API key

# Load the dataset from a specified file path
def Top_Indian_Places_to_Visit('/content/drive/MyDrive/Colab Notebooks/Top Indian Places to Visit.csv'):
    return pd.read_csv(file_path)

# Get recommendations based on user zone
def get_recommendations(data, Zone):
    recommendations = data[data['Zone'].str.contains('|'.join(Zone), case=False)]
    return recommendations

# Generate a detailed itinerary using OpenAI's GPT
def generate_itinerary(location, recommendations):
    prompt = (
        f"You are a knowledgeable tourist guide. Based on the following recommendations for {location}:\n"
    )
    for index, row in recommendations.iterrows():
        prompt += f" - {row['Name']}: {row['Type']}\n"
        prompt += f"   - {row['Establishment Year']}\n"
        prompt += f"   - {row['Significance']}\n"
        prompt += f"   - {row['Best Time to visit']}\n"
    prompt += "Create a 3-day itinerary for someone visiting these places."

    # Set your OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY") # Get the API key from the environment variable

    #If you want to set the key directly, uncomment the line below and replace 'your_api_key' with your actual key
    # openai.api_key = 'your_api_key'

    # Initialize the OpenAI client
    client = OpenAI()
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=300
    )
    return response['choices'][0]['message']['content']

# Main function
if __name__ == "__main__":
    # Specify the file path for the dataset
    file_path = '/content/drive/MyDrive/Colab Notebooks/Top Indian Places to Visit.csv'  # Change this to your actual path

    # Load the dataset
    Top_Indian_Places_to_Visit = Top_Indian_Places_to_Visit(file_path = '/content/drive/MyDrive/Colab Notebooks/Top Indian Places to Visit.csv')

    # Define user inputs
    location = "India"
    interests = ["Establishment Year", "Significance", "Best Time to visit"]  # Example interests


    # Define the zone(s) you want recommendations for
    zone = ["North", "South"]  # Replace with the desired zone(s)


    # Get recommendations based on user zone
    recommendations = top_indian_places[top_indian_places['Zone'].str.contains('|'.join(zone), case=False)]

    # Generate itinerary if there are recommendations
    if not recommendations.empty:
        itinerary = generate_itinerary(location, recommendations)
        print("Itinerary:")
        print(itinerary)
    else:
        print("No recommendations found based on your interests.")
```

        f"You are a knowledgeable tourist guide. Based on the following recommendations for {location}:\n"
    )
    for index, row in recommendations.iterrows():
        prompt += f" - {row['Name']}: {row['Type']}\n"
        prompt += f"   - {row['Establishment Year']}\n"
        prompt += f"   - {row['import requests']}\n"
from openai import OpenAI
import os


# Set your OpenAI API key

# Load the dataset from a specified file path
def Top_Indian_Places_to_Visit(/content/drive/MyDrive/Colab Notebooks/Top Indian Places to Visit.csv):
    return pd.read_csv(file_path)

# Get recommendations based on user zone
def get_recommendations(data, Zone):
    recommendations = data[data['Zone'].str.contains('|'.join(Zone), case=False)]
    return recommendations

# Generate a detailed itinerary using OpenAI's GPT
def generate_itinerary(location, recommendations):
    prompt = (Significance']}\n"
        prompt += f"   - {row['Best Time to visit']}\n"
    prompt += "Create a 3-day itinerary for someone visiting these places."

    # Set your OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY") # Get the API key from the environment variable

    #If you want to set the key directly, uncomment the line below and replace 'your_api_key' with your actual key
    # openai.api_key = 'your_api_key'

    # Initialize the OpenAI client
    client = OpenAI()
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=300
    )
    return response['choices'][0]['message']['content']

# Main function
if __name__ == "__main__":
    # Specify the file path for the dataset
    file_path = '/content/drive/MyDrive/Colab Notebooks/Top Indian Places to Visit.csv'  # Change this to your actual path

    # Load the dataset
    top_indian_places = Top_Indian_Places_to_Visit(file_path = '/content/drive/MyDrive/Colab Notebooks/Top Indian Places to Visit.csv')

    # Define user inputs
    location = "India"
    interests = ["Establishment Year", "Significance", "Best Time to visit"]  # Example interests


    # Define the zone(s) you want recommendations for
    zone = ["North", "South"]  # Replace with the desired zone(s)


    # Get recommendations based on user zone
    recommendations = Top_Indian_Places_to_Visit[Top_Indian_Places_to_Visit['Zone'].str.contains('|'.join(zone), case=False)]

    # Generate itinerary if there are recommendations
    if not recommendations.empty:
        itinerary = generate_itinerary(location, recommendations)
        print("Itinerary:")
        print(itinerary)
    else:
        print("No recommendations found based on your interests.")
```
# Get recommendations based on user zone
def get_recommendations(data, Zone):
    recommendations = data[data['Zone'].str.contains('|'.join(Zone), case=False)]
    return recommendations

# Generate a detailed itinerary using OpenAI's GPT
def generate_itinerary(location, recommendations):
    prompt = (
        f"You are a knowledgeable tourist guide. Based on the following recommendations for {location}:\n"
    )
    for index, row in recommendations.iterrows():
        prompt += f" - {row['Name']}: {row['Type']}\n"
        prompt += f"   - {row['Establishment Year']}\n"
        prompt += f"   - {row['Significance']}\n"
        prompt += f"   - {row['Best Time to visit']}\n"
    prompt += "Create a 3-day itinerary for someone visiting these places."

 # Set your OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY") # Get the API key from the environment variable

    #If you want to set the key directly, uncomment the line below and replace 'your_api_key' with your actual key
    # openai.api_key = 'your_api_key'



    # Initialize the OpenAI client
    client = OpenAI()
response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=300
    )
return response['choices'][0]['message']['content']

# Main function
if __name__ == "__main__":
    # Specify the file path for the dataset
    file_path = '/content/Top Indian Places.csv'  # Change this to your actual path

     # Load the dataset
    Top_Indian_Places_to_Visit = Top_Indian_Places_to_Visit(file_path = r'/content/Top Indian Places.csv')

    # Define user inputs
    location = "India"
    interests = ["Establishment Year", "Significance", "Best Time to visit"]  # Example interests


    # Define the zone(s) you want recommendations for
    zone = ["North", "South"]  # Replace with the desired zone(s)


    # Get recommendations based on user zone
    recommendations = Top_Indian_Places_to_Visit[Top_Indian_Places_to_Visit['Zone'].str.contains('|'.join(zone), case=False)]

    # Generate itinerary if there are recommendations
    if not recommendations.empty:
        itinerary = generate_itinerary(location, recommendations)
        print("Itinerary:")
        print(itinerary)
    else:
        print("No recommendations found based on your interests.")
# Out:
#   File "<tokenize>", line 83
#     )
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# !pip install openai
# !pip install requests
import pandas as pd
import openai
import requests
from openai import OpenAI
import os

# Set your OpenAI API key
# Replace 'your_actual_api_key' with your actual OpenAI API key
os.environ["OPENAI_API_KEY"] = "your_actual_api_key"
# !pip install openai
# !pip install requests
import pandas as pd
import openai
import requests
from openai import OpenAI
import os

# Set your OpenAI API key
# Replace 'your_actual_api_key' with your actual OpenAI API key
os.environ["OPENAI_API_KEY"] = "your_actual_api_key"

# Load the dataset from a specified file path
def load_places_data(file_path='/content/Top Indian Places.csv'):
     return pd.read_csv(r'/content/Top Indian Places.csv')

# Get recommendations based on user zone
def get_recommendations(data, Zone):
    recommendations = data[data['Zone'].str.contains('|'.join(Zone), case=False)]
    return recommendations

# Generate a detailed itinerary using OpenAI's GPT
def generate_itinerary(location, recommendations):
    prompt = (
        f"You are a knowledgeable tourist guide. Based on the following recommendations for {location}:\n"
    )
    for index, row in recommendations.iterrows():
        prompt += f" - {row['Name']}: {row['Type']}\n"
        prompt += f"   - {row['Establishment Year']}\n"
        prompt += f"   - {row['Significance']}\n"
        prompt += f"   - {row['Best Time to visit']}\n"
    prompt += "Create a 3-day itinerary for someone visiting these places."

    # Set your OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY") # Get the API key from the environment variable

    #If you want to set the key directly, uncomment the line below and replace 'your_api_key' with your actual key
    # openai.api_key = 'your_api_key'

    # Initialize the OpenAI client
    client = OpenAI()
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=300
    )
    return response['choices'][0]['message']['content']

# Main function
if __name__ == "__main__":
    # Specify the file path for the dataset
    file_path = '/content/Top Indian Places.csv'  # Change this to your actual path

    # Load the dataset
    top_indian_places = load_places_data(file_path = r'/content/Top Indian Places.csv')

    # Define user inputs
    location = "India"
    interests = ["Establishment Year", "Significance", "Best Time to visit"]  # Example interests

    # Define the zone(s) you want recommendations for
    zone = ["North", "South"]  # Replace with the desired zone(s)

    # Get recommendations based on user zone
    recommendations = top_indian_places[top_indian_places['Zone'].str.contains('|'.join(zone), case=False)]

    # Generate itinerary if there are recommendations
    if not recommendations.empty:
        itinerary = generate_itinerary(location, recommendations)
        print("Itinerary:")
        print(itinerary)
    else:
        print("No recommendations found based on your interests.")
# Get recommendations based on user zone
def get_recommendations(data, Zone):
    recommendations = data[data['Zone'].str.contains('|'.join(Zone), case=False)]
    return recommendations

# Generate a detailed itinerary using OpenAI's GPT
def generate_itinerary(location, recommendations):
    prompt = (
        f"You are a knowledgeable tourist guide. Based on the following recommendations for {location}:\n"
    )
    for index, row in recommendations.iterrows():
        prompt += f" - {row['Name']}: {row['Type']}\n"
        prompt += f"   - {row['Establishment Year']}\n"
        prompt += f"   - {row['Significance']}\n"
        prompt += f"   - {row['Best Time to visit']}\n"
    prompt += "Create a 3-day itinerary for someone visiting these places."

 # Set your OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY") # Get the API key from the environment variable

    #If you want to set the key directly, uncomment the line below and replace 'your_api_key' with your actual key
    # openai.api_key = 'your_api_key'



    # Initialize the OpenAI client
    client = OpenAI()
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        max_tokens=300
    )
    return response['choices'][0]['message']['content']

# Main function
if __name__ == "__main__":
    # Specify the file path for the dataset
    file_path = '/content/Top Indian Places.csv'  # Change this to your actual path

     # Load the dataset
    top_indian_places =load_places_data(file_path = r'/content/Top Indian Places.csv')

    # Define user inputs
    location = "India"
    interests = ["Establishment Year", "Significance", "Best Time to visit"]  # Example interests


    # Define the zone(s) you want recommendations for
    zone = ["North", "South"]  # Replace with the desired zone(s)


    # Get recommendations based on user zone
    recommendations = top_indian_places[top_indian_places['Zone'].str.contains('|'.join(zone), case=False)]

    # Generate itinerary if there are recommendations
    if not recommendations.empty:
        itinerary = generate_itinerary(location, recommendations)
        print("Itinerary:")
        print(itinerary)
    else:
        print("No recommendations found based on your interests.")
